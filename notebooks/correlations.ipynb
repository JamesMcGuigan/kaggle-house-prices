# %% [markdown]
# ## Kaggle Competition - House Prices: Advanced Regression Techniques
# # Correlation Analysis

# %%
import sys
sys.path.append("..")

import pandas as pd
from pandas import DataFrame
import numpy as np
import math
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

from src.Charts import Charts

# %%
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = [25, 15]
pd.options.display.max_columns = None

# %% [markdown]
# ### Load the data

# %%
data = {}
data["train"]    = pd.read_csv("../data/train.csv")                        # Train    dataset contains    SalePrice
data["test"]     = pd.read_csv("../data/test.csv")                         # Test     dataset is without  SalePrice  
data["combined"] = pd.concat([ data["test"], data["train"] ], sort=False)  # Combined dataset has missing SalePrice

# %% [markdown]
# ### Correlations

# %%
Charts.correlation_table(data["train"])
# Out:
# <style  type="text/css" >
#     #T_b391ba9a_3be9_11e9_9bcd_3c07545773e3row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_b391ba9a_3be9_11e9_9bcd_3c07545773e3row0_col1 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_b391ba9a_3be9_11e9_9bcd_3c07545773e3row0_col2 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_b391ba9a_3be9_11e9_9bcd_3c07545773e3row0_col3 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_b391ba9a_3be9_11e9_9bcd_3c07545773e3row0_col4 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_b391ba9a_3be9_11e9_9bcd_3c07545773e3row0_col5 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_b391ba9a_3be9_11e9_9bcd_3c07545773e3row0_col6 {
#             background-color:  #c9cee4;
#             color:  #000000;
# ...

# %%
Charts.heatmap(data["train"])

# %%
# Charts.scatter_matrix(data["train"]);  # Very slow function

# %% [markdown]
# Which columns are most correlated to SalesPrice?

# %%
SalePrice = data["train"].corr().SalePrice
SalePrice[abs(SalePrice) > 0.3].sort_values(ascending=False)
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# GarageYrBlt     0.486362
# MasVnrArea      0.477493
# Fireplaces      0.466929
# BsmtFinSF1      0.386420
# LotFrontage     0.351799
# WoodDeckSF      0.324413
# 2ndFlrSF        0.319334
# OpenPorchSF     0.315856
# Name: SalePrice, dtype: float64

# %%
SalePrice[abs(SalePrice) > 0.3].index
# Out:
# Index(['LotFrontage', 'OverallQual', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#        'BsmtFinSF1', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'GrLivArea',
#        'FullBath', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars',
#        'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'SalePrice'],
#       dtype='object')

# %%
correlated_column_names = SalePrice[abs(SalePrice) > 0.3].index
df_correlated = data["train"][ correlated_column_names ]
Charts.scatter_matrix( df_correlated );
